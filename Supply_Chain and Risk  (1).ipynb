# %%
import pandas as pd 
df = pd.read_csv("C:/Users/PC/Downloads/jupiter/Supply_Chain_and risk_performance.csv")

# %%
df.head()
# Out:
#   Order_ID Buyer_ID Supplier_ID Product_Category  Quantity_Ordered  \
# 0    O1000      B33         S23         Textiles               469
# 1    O1001       B1         S20        Machinery               365
# 2    O1002       B2         S10             Food               333
# 3    O1003       B6         S10        Machinery               142
# 4    O1004       B5          S4        Machinery               897
#
#    Order_Date Dispatch_Date Delivery_Date Shipping_Mode  Order_Value_USD  ...  \
# 0  2023-10-24    2023-10-27    2023-10-28          Rail         36273.99  ...
# 1  2023-07-07    2023-07-08    2023-07-09          Road         34780.36  ...
# 2  2023-12-28    2023-12-29    2024-01-07          Rail          7154.54  ...
# 3  2023-01-14    2023-01-17    2023-01-20          Rail         15320.08  ...
# 4  2023-01-12    2023-01-14    2023-01-16          Road         18256.42  ...
#
#    Supplier_Reliability_Score Organization_ID Dominant_Buyer_Flag  \
# ...

# %%
df.shape
# Out:
# (1000, 24)

# %%
df.info
# Out:
# <bound method DataFrame.info of     Order_ID Buyer_ID Supplier_ID Product_Category  Quantity_Ordered  \
# 0      O1000      B33         S23         Textiles               469
# 1      O1001       B1         S20        Machinery               365
# 2      O1002       B2         S10             Food               333
# 3      O1003       B6         S10        Machinery               142
# 4      O1004       B5          S4        Machinery               897
# ..       ...      ...         ...              ...               ...
# 995    O1995      B23         S27           Pharma                31
# 996    O1996      B45          S2      Electronics               419
# 997    O1997      B22         S24      Electronics               904
# 998    O1998      B10         S26         Textiles               524
# 999    O1999       B4          S9             Food               136
#
#      Order_Date Dispatch_Date Delivery_Date Shipping_Mode  Order_Value_USD  \
# ...

# %%
df.describe()
# Out:
#        Quantity_Ordered  Order_Value_USD   Delay_Days  \
# count       1000.000000      1000.000000  1000.000000
# mean         504.288000     25290.073670     1.943000
# std          295.545455     14380.329641     2.852699
# min           10.000000       500.580000     0.000000
# 25%          248.000000     12891.837500     0.000000
# 50%          499.000000     25596.005000     1.000000
# 75%          760.500000     37574.430000     3.000000
# max          999.000000     49945.180000    10.000000
#
#        Historical_Disruption_Count  Supplier_Reliability_Score  \
# count                  1000.000000                 1000.000000
# mean                      9.841000                    0.745760
# std                       5.656652                    0.143063
# min                       0.000000                    0.500000
# 25%                       5.000000                    0.620000
# 50%                      10.000000                    0.740000
# ...

# %%
df["Delay_Days"].describe()
# Out:
# count    1000.000000
# mean        1.943000
# std         2.852699
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        10.000000
# Name: Delay_Days, dtype: float64

# %%
df.isnull().sum()
# Out:
# Order_ID                          0
# Buyer_ID                          0
# Supplier_ID                       0
# Product_Category                  0
# Quantity_Ordered                  0
# Order_Date                        0
# Dispatch_Date                     0
# Delivery_Date                     0
# Shipping_Mode                     0
# Order_Value_USD                   0
# Delay_Days                        0
# Disruption_Type                 486
# Disruption_Severity             486
# Historical_Disruption_Count       0
# Supplier_Reliability_Score        0
# Organization_ID                   0
# Dominant_Buyer_Flag               0
# Available_Historical_Records      0
# Data_Sharing_Consent              0
# Federated_Round                   0
# Parameter_Change_Magnitude        0
# Communication_Cost_MB             0
# Energy_Consumption_Joules         0
# Supply_Risk_Flag                  0
# dtype: int64

# %%
df[" Disruption_Type"]= df["Disruption_Type"].fillna("No Disruption")

# %%
df.columns
# Out:
# Index(['Order_ID', 'Buyer_ID', 'Supplier_ID', 'Product_Category',
#        'Quantity_Ordered', 'Order_Date', 'Dispatch_Date', 'Delivery_Date',
#        'Shipping_Mode', 'Order_Value_USD', 'Delay_Days', 'Disruption_Type',
#        'Disruption_Severity', 'Historical_Disruption_Count',
#        'Supplier_Reliability_Score', 'Organization_ID', 'Dominant_Buyer_Flag',
#        'Available_Historical_Records', 'Data_Sharing_Consent',
#        'Federated_Round', 'Parameter_Change_Magnitude',
#        'Communication_Cost_MB', 'Energy_Consumption_Joules',
#        'Supply_Risk_Flag', ' Disruption_Type'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Order_ID                      1000 non-null   object
#  1   Buyer_ID                      1000 non-null   object
#  2   Supplier_ID                   1000 non-null   object
#  3   Product_Category              1000 non-null   object
#  4   Quantity_Ordered              1000 non-null   int64
#  5   Order_Date                    1000 non-null   object
#  6   Dispatch_Date                 1000 non-null   object
#  7   Delivery_Date                 1000 non-null   object
#  8   Shipping_Mode                 1000 non-null   object
#  9   Order_Value_USD               1000 non-null   float64
#  10  Delay_Days                    1000 non-null   int64
#  11  Disruption_Type               514 non-null    object
# ...

# %%
df.isnull().sum()
# Out:
# Order_ID                          0
# Buyer_ID                          0
# Supplier_ID                       0
# Product_Category                  0
# Quantity_Ordered                  0
# Order_Date                        0
# Dispatch_Date                     0
# Delivery_Date                     0
# Shipping_Mode                     0
# Order_Value_USD                   0
# Delay_Days                        0
# Disruption_Type                 486
# Disruption_Severity             486
# Historical_Disruption_Count       0
# Supplier_Reliability_Score        0
# Organization_ID                   0
# Dominant_Buyer_Flag               0
# Available_Historical_Records      0
# Data_Sharing_Consent              0
# Federated_Round                   0
# Parameter_Change_Magnitude        0
# Communication_Cost_MB             0
# Energy_Consumption_Joules         0
# Supply_Risk_Flag                  0
#  Disruption_Type                  0
# dtype: int64

# %%
df["Disruption_Type"]=df["Disruption_Type"].fillna("No Disruption")
df["Disruption_Severity"]=df["Disruption_Severity"].fillna("No Impact")

# %%
df.isnull().sum()
# Out:
# Order_ID                        0
# Buyer_ID                        0
# Supplier_ID                     0
# Product_Category                0
# Quantity_Ordered                0
# Order_Date                      0
# Dispatch_Date                   0
# Delivery_Date                   0
# Shipping_Mode                   0
# Order_Value_USD                 0
# Delay_Days                      0
# Disruption_Type                 0
# Disruption_Severity             0
# Historical_Disruption_Count     0
# Supplier_Reliability_Score      0
# Organization_ID                 0
# Dominant_Buyer_Flag             0
# Available_Historical_Records    0
# Data_Sharing_Consent            0
# Federated_Round                 0
# Parameter_Change_Magnitude      0
# Communication_Cost_MB           0
# Energy_Consumption_Joules       0
# Supply_Risk_Flag                0
#  Disruption_Type                0
# dtype: int64

# %%
df= df.drop(columns = ["Organization_ID","Available_Historical_Records","Data_Sharing_Consent","Federated_Round","Parameter_Change_Magnitude",])

# %%
df.columns
# Out:
# Index(['Order_ID', 'Buyer_ID', 'Supplier_ID', 'Product_Category',
#        'Quantity_Ordered', 'Order_Date', 'Dispatch_Date', 'Delivery_Date',
#        'Shipping_Mode', 'Order_Value_USD', 'Delay_Days', 'Disruption_Type',
#        'Disruption_Severity', 'Historical_Disruption_Count',
#        'Supplier_Reliability_Score', 'Dominant_Buyer_Flag',
#        'Communication_Cost_MB', 'Energy_Consumption_Joules',
#        'Supply_Risk_Flag', ' Disruption_Type'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 20)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.columns = df. columns.str.strip()

# %%
df.columns = df.columns.str.lower()

# %%
df= df.loc[:, ~df.columns.duplicated()]

# %%
df.dtypes
# Out:
# order_id                        object
# buyer_id                        object
# supplier_id                     object
# product_category                object
# quantity_ordered                 int64
# order_date                      object
# dispatch_date                   object
# delivery_date                   object
# shipping_mode                   object
# order_value_usd                float64
# delay_days                       int64
# disruption_type                 object
# disruption_severity             object
# historical_disruption_count      int64
# supplier_reliability_score     float64
# dominant_buyer_flag              int64
# communication_cost_mb          float64
# energy_consumption_joules      float64
# supply_risk_flag                 int64
# dtype: object

# %%
date_cols=["order_date","dispatch_date","delivery_date"]
df[date_cols]= df[date_cols].apply(pd.to_datetime)

# %%
df.dtypes
# Out:
# order_id                               object
# buyer_id                               object
# supplier_id                            object
# product_category                       object
# quantity_ordered                        int64
# order_date                     datetime64[ns]
# dispatch_date                  datetime64[ns]
# delivery_date                  datetime64[ns]
# shipping_mode                          object
# order_value_usd                       float64
# delay_days                              int64
# disruption_type                        object
# disruption_severity                    object
# historical_disruption_count             int64
# supplier_reliability_score            float64
# dominant_buyer_flag                     int64
# communication_cost_mb                 float64
# energy_consumption_joules             float64
# supply_risk_flag                        int64
# dtype: object

# %%
df[ df["delivery_date"]< df["order_date"]]
# Out:
# Empty DataFrame
# Columns: [order_id, buyer_id, supplier_id, product_category, quantity_ordered, order_date, dispatch_date, delivery_date, shipping_mode, order_value_usd, delay_days, disruption_type, disruption_severity, historical_disruption_count, supplier_reliability_score, dominant_buyer_flag, communication_cost_mb, energy_consumption_joules, supply_risk_flag]
# Index: []

# %%
df[df["delay_days"]<0]
# Out:
# Empty DataFrame
# Columns: [order_id, buyer_id, supplier_id, product_category, quantity_ordered, order_date, dispatch_date, delivery_date, shipping_mode, order_value_usd, delay_days, disruption_type, disruption_severity, historical_disruption_count, supplier_reliability_score, dominant_buyer_flag, communication_cost_mb, energy_consumption_joules, supply_risk_flag]
# Index: []

# %%
df[df["quantity_ordered"]<=0]
# Out:
# Empty DataFrame
# Columns: [order_id, buyer_id, supplier_id, product_category, quantity_ordered, order_date, dispatch_date, delivery_date, shipping_mode, order_value_usd, delay_days, disruption_type, disruption_severity, historical_disruption_count, supplier_reliability_score, dominant_buyer_flag, communication_cost_mb, energy_consumption_joules, supply_risk_flag]
# Index: []

# %%
df['dispatch_time']= (df['dispatch_date']-df['order_date']).dt.days ##Delivery Performance
df['delivery_time']=(df['delivery_date']-df['dispatch_date']).dt.days ##shippment effienecy
df['total_fullfilment_time']=(df['delivery_date']-df['order_date']).dt.days ## delay analysis

# %%
df.head()
# Out:
#   order_id buyer_id supplier_id product_category  quantity_ordered order_date  \
# 0    O1000      B33         S23         Textiles               469 2023-10-24
# 1    O1001       B1         S20        Machinery               365 2023-07-07
# 2    O1002       B2         S10             Food               333 2023-12-28
# 3    O1003       B6         S10        Machinery               142 2023-01-14
# 4    O1004       B5          S4        Machinery               897 2023-01-12
#
#   dispatch_date delivery_date shipping_mode  order_value_usd  ...  \
# 0    2023-10-27    2023-10-28          Rail         36273.99  ...
# 1    2023-07-08    2023-07-09          Road         34780.36  ...
# 2    2023-12-29    2024-01-07          Rail          7154.54  ...
# 3    2023-01-17    2023-01-20          Rail         15320.08  ...
# 4    2023-01-14    2023-01-16          Road         18256.42  ...
#
#    disruption_severity historical_disruption_count supplier_reliability_score  \
# ...

# %%
pip install psycopg2 sqlalchemy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine(
"postgresql://postgres:admin123@localhost:5432/Supply_chain_db"
)

# %%
print(df.shape)
# Out:
# (1000, 22)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.to_sql(
"supply_chain",
engine,
if_exists="replace",
index=False
)
# Out:
# 1000

# %%
df.to_csv("final_supply_chain.csv", index=False)

# %%
whos
# Out:
# Variable               Type         Data/Info
# ---------------------------------------------
# create_engine          function     <function create_engine at 0x000001A4240F1620>
# dataframe_columns      function     <function dataframe_colum<...>ns at 0x000001A42375F920>
# dataframe_hash         function     <function dataframe_hash at 0x000001A42375F2E0>
# date_cols              list         n=3
# df                     DataFrame    Shape: (1000, 22)
# dtypes_str             function     <function dtypes_str at 0x000001A42375E5C0>
# engine                 Engine       Engine(postgresql://postg<...>ost:5432/Supply_chain_db)
# get_dataframes         function     <function get_dataframes at 0x000001A42375F9C0>
# getpass                module       <module 'getpass' from 'C<...>conda3\\Lib\\getpass.py'>
# hashlib                module       <module 'hashlib' from 'C<...>conda3\\Lib\\hashlib.py'>
# ...

# %%
df.to_csv(
"final_supply_chain.csv",
index=False
)

# %%
import os

print(os.listdir())
# Out:
# ['.anaconda', '.cache', '.conda', '.continuum', '.docker', '.ipynb_checkpoints', '.ipython', '.jupyter', '.ms-ad', '.n8n', '.ollama', '3D Objects', 'anaconda3', 'anaconda_projects', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Customer_shopping_behavior.ipynb', 'Customer_Shopping_Behavior_Analysis.ipynb', 'Documents', 'Downloads', 'edb_pgbouncer.exe', 'Favorites', 'final_supply_chain.csv', 'IntelGraphicsProfiles', 'Links', 'Local Settings', 'Microsoft', 'Music', 'My Documents', 'n8n', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{e5196647-e22e-11ee-b534-283926191a07}.TM.blf', 'NTUSER.DAT{e5196647-e22e-11ee-b534-283926191a07}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{e5196647-e22e-11ee-b534-283926191a07}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'postgresql_13.exe', 'postgresql_17.exe', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'shopping_behavior_updated (1).csv', 'Start Menu', 'Supp
# ...
